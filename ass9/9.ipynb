# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset('titanic')

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data['sex'].replace({"female":0,"male":1},inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3552\2081630093.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['sex'].replace({"female":0,"male":1},inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3552\2081630093.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
def fun2(value):
    if (value == 'S'):
        return 0
    elif (value == 'C'):
        return 1
    elif (value == 'Q'):
        return 2
    else:
        return 0


data["embarked"] = data["embarked"].apply(fun2)

# %%
age_mean = data['age'].mean()
data['age'].fillna(age_mean)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    14.375244
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         0  Third    man
# 1         1       1    0  38.0      1      0  71.2833         1  First  woman
# 2         1       3    0  26.0      0      0   7.9250         0  Third  woman
# 3         1       1    0  35.0      1      0  53.1000         0  First  woman
# 4         0       3    1  35.0      0      0   8.0500         0  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         0  Third    man
# 1         1       1    0  38.0      1      0  71.2833         1  First  woman
# 2         1       3    0  26.0      0      0   7.9250         0  Third  woman
# 3         1       1    0  35.0      1      0  53.1000         0  First  woman
# 4         0       3    1  35.0      0      0   8.0500         0  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='sex', y='age', hue='survived', data=data);
plt.show()

# %%
grouped = data.groupby(['sex', 'survived'])['age'].describe()

# Print the statistics
print(grouped)
# Out:
#               count       mean        std       min        25%   50%  \
# sex survived
# 0   0          81.0  25.974844  13.778101  2.000000  17.000000  25.0
#     1         233.0  28.654538  14.241985 -9.127124  19.000000  28.0
# 1   0         468.0  31.226848  14.928625 -6.364261  21.000000  29.0
#     1         109.0  27.285816  16.054347  0.420000  18.811447  28.0
#
#                    75%   max
# sex survived
# 0   0         37.73604  57.0
#     1         37.97608  63.0
# 1   0         40.62500  74.0
#     1         36.00000  80.0

# %%
print("\nObservations:")
for (sex, survived), group in data.groupby(['sex', 'survived']):
    print(f"\nIn the category {sex}, {'survivors' if survived else 'non-survivors'}:")
    print(f"- Mean Age: {group['age'].mean():.2f}")
    print(f"- Median Age: {group['age'].median():.2f}")
    print(f"- Age Range: {group['age'].min():.2f} to {group['age'].max():.2f}")

    # Determine the opposite survival status
    opposite_survived = 0 if survived else 1

    # Check if the opposite survival status exists in the grouped data
    if (sex, opposite_survived) in grouped.index:
        opposite_median = grouped.loc[(sex, opposite_survived), '50%']
        if group['age'].median() < opposite_median:
            print("  Median age of survivors is lower than non-survivors.")
        else:
            print("  Median age of survivors is higher than non-survivors.")
    else:
        print(f"  No comparable data for {sex} {'non-survivors' if survived else 'survivors'}.")
# Out:
# Observations:
#
# In the category 0, non-survivors:
# - Mean Age: 25.97
# - Median Age: 25.00
# - Age Range: 2.00 to 57.00
#   Median age of survivors is lower than non-survivors.
#
# In the category 0, survivors:
# - Mean Age: 28.65
# - Median Age: 28.00
# - Age Range: -9.13 to 63.00
#   Median age of survivors is higher than non-survivors.
#
# In the category 1, non-survivors:
# - Mean Age: 31.23
# - Median Age: 29.00
# - Age Range: -6.36 to 74.00
#   Median age of survivors is higher than non-survivors.
#
# In the category 1, survivors:
# - Mean Age: 27.29
# - Median Age: 28.00
# - Age Range: 0.42 to 80.00
#   Median age of survivors is lower than non-survivors.
