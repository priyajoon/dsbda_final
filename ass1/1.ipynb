# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('train.csv')

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 183          184         1       2  Becker, Master. Richard F    male   1.0
# 253          254         0       3   Lobb, Mr. William Arthur    male  30.0
# 0              1         0       3    Braund, Mr. Owen Harris    male  22.0
# 109          110         1       3        Moran, Miss. Bertha  female   NaN
# 524          525         0       3          Kassem, Mr. Fared    male   NaN
#
#      SibSp  Parch     Ticket     Fare Cabin Embarked
# 183      2      1     230136  39.0000    F4        S
# 253      1      0  A/5. 3336  16.1000   NaN        S
# 0        1      0  A/5 21171   7.2500   NaN        S
# 109      1      0     371110  24.1500   NaN        Q
# 524      0      0       2700   7.2292   NaN        C

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.size
# Out:
# 10692

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (891, 12)

# %%
data.dropna()

# If you want to drop columns with any missing values, you would specify axis=1
# cleaned_data = data.dropna(axis=1)

# If you want to drop rows or columns only if all elements are missing, you would specify how='all'
# cleaned_data = data.dropna(how='all')

# If you want to drop rows or columns based on a subset of columns, you can specify subset
# cleaned_data = data.dropna(subset=['column1', 'column2'])

# If you want to modify 'data' in place without assigning it to a new variable
# data.dropna(inplace=True)

# Now 'cleaned_data' contains the DataFrame with rows containing missing values removed
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=data.dropna()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["Sex"].replace({"female":0,"male":1},inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 6                              McCarthy, Mr. Timothy J    1  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut    0   4.0      1
# 11                            Bonnell, Miss. Elizabeth    0  58.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data['Sex'].value_counts()
# Out:
# Sex
# 1    95
# 0    88
# Name: count, dtype: int64

# %%
#pip install seaborn
data['Age']=data['Age'].astype(int)

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name  Sex  Age  SibSp  Parch  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1      0
# 6                             McCarthy, Mr. Timothy J    1   54      0      0
# 10                    Sandstrom, Miss. Marguerite Rut    0    4      1      1
# 11                           Bonnell, Miss. Elizabeth    0   58      0      0
#
#       Ticket     Fare Cabin Embarked
# 1   PC 17599  71.2833   C85        C
# 3     113803  53.1000  C123        S
# 6      17463  51.8625   E46        S
# 10   PP 9549  16.7000    G6        S
# 11    113783  26.5500  C103        S

# %%
sns.countplot(data=data, x= 'Sex', hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# def cat_to_num(value):
#     if(value=="male"):
#         return 1
#     elif(value=="female"):
#         return 0
#     else:
#         pass

# %%
# data["Sex"]=data["Sex"].apply(cat_to_num)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age              int32
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
